# %%
import numpy as np

# %% [markdown]
# Input

# %%
X=np.array([[0,0,1,1],[0,1,0,1]])
print(f'{X.shape=}')
# Out:
# X.shape=(2, 4)

# %% [markdown]
# Parameters

# %%
W=np.array([[1,1]])
print(f'{W.shape=}')
# Out:
# W.shape=(1, 2)

# %%
theta=1

# %%
Z=W@X
print(f'{Z=}')
# Out:
# Z=array([[0, 1, 1, 2]])

# %%
y_pred= [int(pred >= theta) for pred in Z.ravel()]
print(f'{y_pred =}')
# Out:
# y_pred =[0, 1, 1, 1]
